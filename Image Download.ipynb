# %%
import requests
import os
from tqdm import tqdm

# Species and target image counts
species_targets = {
    "Pinus pinaster": 200,
    "Quercus suber": 200,
    "Eucalyptus globulus": 200,
}

output_folder = "data_images"

# Acceptable image formats
valid_extensions = (".jpg", ".jpeg")

# Create main output folder
os.makedirs(output_folder, exist_ok=True)

def get_occurrences(scientific_name, offset=0, limit=300):
    url = "https://api.gbif.org/v1/occurrence/search"
    params = {
        "scientificName": scientific_name,
        "country": "PT",
        "mediaType": "StillImage",
        "hasCoordinate": "true",
        "license": "CC_BY_4_0",
        "limit": limit,
        "offset": offset
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json()

def download_image(image_url, file_path):
    try:
        r = requests.get(image_url, stream=True, timeout=10)
        if r.status_code == 200:
            with open(file_path, "wb") as f:
                for chunk in r.iter_content(1024):
                    f.write(chunk)
    except Exception as e:
        print(f"Error downloading {image_url}: {e}")

# Loop through each species
for species_name, target_count in species_targets.items():
    print(f"\n🔍 Searching for images of: {species_name}...")

    downloaded = 300
    offset = 300
    max_images = 500

    while downloaded < max_images:
        data = get_occurrences(species_name, offset=offset, limit=900)
        results = data.get("results", [])
        if not results:
            print("No more results found.")
            break

        for record in results:
            if downloaded >= max_images:
                break
            for m in record.get("media", []):
                image_url = m.get("identifier", "")
                if image_url and image_url.lower().endswith(valid_extensions):
                    ext = os.path.splitext(image_url)[-1]
                    file_path = os.path.join(
                        output_folder,
                        f"{species_name.replace(' ', '_')}_{downloaded:04d}{ext}"
                    )
                    download_image(image_url, file_path)
                    downloaded += 1
                    if downloaded >= max_images:
                        break

        offset += len(results)

    print(f"✅ {downloaded} images saved to: {output_folder}")

print("\n📁 All images have been downloaded successfully.")
# Out:
# 🔍 Searching for images of: Pinus pinaster...
# No more results found.
# ✅ 457 images saved to: data_images
#
# 🔍 Searching for images of: Quercus suber...
# ✅ 500 images saved to: data_images
#
# 🔍 Searching for images of: Eucalyptus globulus...
# ✅ 500 images saved to: data_images
#
# 📁 All images have been downloaded successfully.

# %%
import os
import re
from collections import defaultdict

# Caminho da pasta com as imagens
folder = 'data_images'

# Expressão regular para capturar o nome da espécie e ignorar o número
pattern = re.compile(r'^(.*?)_\d+\.(\w+)$')

# Dicionário para armazenar listas de arquivos por espécie
species_files = defaultdict(list)

# Organizar os arquivos por espécie
for filename in os.listdir(folder):
    match = pattern.match(filename)
    if match:
        species_name, ext = match.groups()
        species_files[species_name].append((filename, ext))

# Renomear os arquivos de forma sequencial por espécie
for species, files in species_files.items():
    files.sort()  # Ordena para consistência
    for idx, (old_name, ext) in enumerate(files):
        new_name = f"{species}_{idx:04d}.{ext}"
        src = os.path.join(folder, old_name)
        dst = os.path.join(folder, new_name)
        os.rename(src, dst)
        print(f"Renamed: {old_name} → {new_name}")
# Out:
# Renamed: Eucalyptus_globulus_0000.jpg → Eucalyptus_globulus_0000.jpg
# Renamed: Eucalyptus_globulus_0001.jpg → Eucalyptus_globulus_0001.jpg
# Renamed: Eucalyptus_globulus_0002.jpeg → Eucalyptus_globulus_0002.jpeg
# Renamed: Eucalyptus_globulus_0003.jpeg → Eucalyptus_globulus_0003.jpeg
# Renamed: Eucalyptus_globulus_0004.jpeg → Eucalyptus_globulus_0004.jpeg
# Renamed: Eucalyptus_globulus_0005.jpeg → Eucalyptus_globulus_0005.jpeg
# Renamed: Eucalyptus_globulus_0006.jpeg → Eucalyptus_globulus_0006.jpeg
# Renamed: Eucalyptus_globulus_0007.jpeg → Eucalyptus_globulus_0007.jpeg
# Renamed: Eucalyptus_globulus_0008.jpg → Eucalyptus_globulus_0008.jpg
# Renamed: Eucalyptus_globulus_0009.jpg → Eucalyptus_globulus_0009.jpg
# Renamed: Eucalyptus_globulus_0010.jpeg → Eucalyptus_globulus_0010.jpeg
# Renamed: Eucalyptus_globulus_0011.jpeg → Eucalyptus_globulus_0011.jpeg
# Renamed: Eucalyptus_globulus_0012.jpeg → Eucalyptus_globulus_0012.jpeg
# Renamed: Eucalyptus_globulus_0013.jpg → Eucalyptus_globulus_0013.jpg
# Renamed: Eucalyptus_globulus_0014.jpeg → Eucalyptus_globulus_0014.jpeg
# Renamed: Eucalyptus_globulus_0015.jpg → Eucalyptus_globulus_0015.jpg
# Renamed: Eucalyptus_globulus_0016.jpeg → Eucalyptus_globulus_0016.jpeg
# Renamed: Eucalyptus_globulus_0017.jpg → Eucalyptus_globulus_0017.jpg
# Renamed: Eucalyptus_globulus_0018.jpg → Eucalyptus_globulus_0018.jpg
# Renamed: Eucalyptus_globulus_0019.jpeg → Eucalyptus_globulus_0019.jpeg
# Renamed: Eucalyptus_globulus_0020.jpeg → Eucalyptus_globulus_0020.jpeg
# Renamed: Eucalyptus_globulus_0021.jpg → Eucalyptus_globulus_0021.jpg
# Renamed: Eucalyptus_globulus_0022.jpeg → Eucalyptus_globulus_0022.jpeg
# Renamed: Eucalyptus_globulus_0023.jpeg → Eucalyptus_globulus_0023.jpeg
# Renamed: Eucalyptus_globulus_0024.jpg → Eucalyptus_globulus_0024.jpg
# Renamed: Eucalyptus_globulus_0025.jpeg → Eucalyptus_globulus_0025.jpeg
# Renamed: Eucalyptus_globulus_0026.jpeg → Eucalyptus_globulus_0026.jpeg
# Renamed: Eucalyptus_globulus_0027.jpeg → Eucalyptus_globulus_0027.jpeg
# Renamed: Eucalyptus_globulus_0028.jpeg → Eucalyptus_globulus_0028.jpeg
# Renamed: Eucalyptus_globulus_0029.jpeg → Eucalyptus_globulus_0029.jpeg
# Renamed: Eucalyptus_globulus_0030.jpeg → Eucalyptus_globulus_0030.jpeg
# Renamed: Eucalyptus_globulus_0031.jpeg → Eucalyptus_globulus_0031.jpeg
# Renamed: Eucalyptus_globulus_0032.jpeg → Eucalyptus_globulus_0032.jpeg
# Renamed: Eucalyptus_globulus_0033.jpeg → Eucalyptus_globulus_0033.jpeg
# Renamed: Eucalyptus_globulus_0034.jpeg → Eucalyptus_globulus_0034.jpeg
# Renamed: Eucalyptus_globulus_0035.jpeg → Eucalyptus_globulus_0035.jpeg
# Renamed: Eucalyptus_globulus_0036.jpeg → Eucalyptus_globulus_0036.jpeg
# Renamed: Eucalyptus_globulus_0037.jpg → Eucalyptus_globulus_0037.jpg
# Renamed: Eucalyptus_globulus_0038.jpg → Eucalyptus_globulus_0038.jpg
# Renamed: Eucalyptus_globulus_0039.jpg → Eucalyptus_globulus_0039.jpg
# Renamed: Eucalyptus_globulus_0040.jpeg → Eucalyptus_globulus_0040.jpeg
# Renamed: Eucalyptus_globulus_0041.jpeg → Eucalyptus_globulus_0041.jpeg
# Renamed: Eucalyptus_globulus_0042.jpeg → Eucalyptus_globulus_0042.jpeg
# Renamed: Eucalyptus_globulus_0043.jpeg → Eucalyptus_globulus_0043.jpeg
# Renamed: Eucalyptus_globulus_0044.jpeg → Eucalyptus_globulus_0044.jpeg
# Renamed: Eucalyptus_globulus_0045.jpeg → Eucalyptus_globulus_0045.jpeg
# Renamed: Eucalyptus_globulus_0046.jpeg → Eucalyptus_globulus_0046.jpeg
# Renamed: Eucalyptus_globulus_0047.jpeg → Eucalyptus_globulus_0047.jpeg
# Renamed: Eucalyptus_globulus_0048.jpeg → Eucalyptus_globulus_0048.jpeg
# Renamed: Eucalyptus_globulus_0049.jpeg → Eucalyptus_globulus_0049.jpeg
# Renamed: Eucalyptus_globulus_0050.jpeg → Eucalyptus_globulus_0050.jpeg
# Renamed: Eucalyptus_globulus_0051.jpeg → Eucalyptus_globulus_0051.jpeg
# Renamed: Eucalyptus_globulus_0052.jpeg → Eucalyptus_globulus_0052.jpeg
# Renamed: Eucalyptus_globulus_0053.jpeg → Eucalyptus_globulus_0053.jpeg
# Renamed: Eucalyptus_globulus_0054.jpeg → Eucalyptus_globulus_0054.jpeg
# Renamed: Eucalyptus_globulus_0055.jpeg → Eucalyptus_globulus_0055.jpeg
# Renamed: Eucalyptus_globulus_0056.jpeg → Eucalyptus_globulus_0056.jpeg
# Renamed: Eucalyptus_globulus_0057.jpeg → Eucalyptus_globulus_0057.jpeg
# Renamed: Eucalyptus_globulus_0058.jpeg → Eucalyptus_globulus_0058.jpeg
# Renamed: Eucalyptus_globulus_0059.jpeg → Eucalyptus_globulus_0059.jpeg
# Renamed: Eucalyptus_globulus_0060.jpeg → Eucalyptus_globulus_0060.jpeg
# Renamed: Eucalyptus_globulus_0061.jpeg → Eucalyptus_globulus_0061.jpeg
# Renamed: Eucalyptus_globulus_0062.jpeg → Eucalyptus_globulus_0062.jpeg
# Renamed: Eucalyptus_globulus_0063.jpeg → Eucalyptus_globulus_0063.jpeg
# Renamed: Eucalyptus_globulus_0064.jpeg → Eucalyptus_globulus_0064.jpeg
# Renamed: Eucalyptus_globulus_0065.jpeg → Eucalyptus_globulus_0065.jpeg
# Renamed: Eucalyptus_globulus_0066.jpeg → Eucalyptus_globulus_0066.jpeg
# Renamed: Eucalyptus_globulus_0067.jpeg → Eucalyptus_globulus_0067.jpeg
# Renamed: Eucalyptus_globulus_0068.jpeg → Eucalyptus_globulus_0068.jpeg
# Renamed: Eucalyptus_globulus_0069.jpeg → Eucalyptus_globulus_0069.jpeg
# Renamed: Eucalyptus_globulus_0070.jpeg → Eucalyptus_globulus_0070.jpeg
# Renamed: Eucalyptus_globulus_0071.jpeg → Eucalyptus_globulus_0071.jpeg
# Renamed: Eucalyptus_globulus_0072.jpeg → Eucalyptus_globulus_0072.jpeg
# Renamed: Eucalyptus_globulus_0073.jpeg → Eucalyptus_globulus_0073.jpeg
# Renamed: Eucalyptus_globulus_0074.jpeg → Eucalyptus_globulus_0074.jpeg
# Renamed: Eucalyptus_globulus_0075.jpeg → Eucalyptus_globulus_0075.jpeg
# Renamed: Eucalyptus_globulus_0076.jpeg → Eucalyptus_globulus_0076.jpeg
# Renamed: Eucalyptus_globulus_0077.jpeg → Eucalyptus_globulus_0077.jpeg
# Renamed: Eucalyptus_globulus_0078.jpeg → Eucalyptus_globulus_0078.jpeg
# Renamed: Eucalyptus_globulus_0079.jpeg → Eucalyptus_globulus_0079.jpeg
# Renamed: Eucalyptus_globulus_0080.jpeg → Eucalyptus_globulus_0080.jpeg
# Renamed: Eucalyptus_globulus_0081.jpeg → Eucalyptus_globulus_0081.jpeg
# Renamed: Eucalyptus_globulus_0082.jpeg → Eucalyptus_globulus_0082.jpeg
# Renamed: Eucalyptus_globulus_0083.jpeg → Eucalyptus_globulus_0083.jpeg
# Renamed: Eucalyptus_globulus_0084.jpeg → Eucalyptus_globulus_0084.jpeg
# Renamed: Eucalyptus_globulus_0085.jpeg → Eucalyptus_globulus_0085.jpeg
# Renamed: Eucalyptus_globulus_0086.jpeg → Eucalyptus_globulus_0086.jpeg
# Renamed: Eucalyptus_globulus_0087.jpeg → Eucalyptus_globulus_0087.jpeg
# Renamed: Eucalyptus_globulus_0088.jpeg → Eucalyptus_globulus_0088.jpeg
# Renamed: Eucalyptus_globulus_0089.jpeg → Eucalyptus_globulus_0089.jpeg
# Renamed: Eucalyptus_globulus_0090.jpeg → Eucalyptus_globulus_0090.jpeg
# Renamed: Eucalyptus_globulus_0091.jpeg → Eucalyptus_globulus_0091.jpeg
# Renamed: Eucalyptus_globulus_0092.jpeg → Eucalyptus_globulus_0092.jpeg
# Renamed: Eucalyptus_globulus_0093.jpeg → Eucalyptus_globulus_0093.jpeg
# Renamed: Eucalyptus_globulus_0094.jpeg → Eucalyptus_globulus_0094.jpeg
# Renamed: Eucalyptus_globulus_0095.jpeg → Eucalyptus_globulus_0095.jpeg
# Renamed: Eucalyptus_globulus_0096.jpeg → Eucalyptus_globulus_0096.jpeg
# Renamed: Eucalyptus_globulus_0097.jpeg → Eucalyptus_globulus_0097.jpeg
# Renamed: Eucalyptus_globulus_0098.jpeg → Eucalyptus_globulus_0098.jpeg
# Renamed: Eucalyptus_globulus_0099.jpeg → Eucalyptus_globulus_0099.jpeg
# Renamed: Eucalyptus_globulus_0100.jpeg → Eucalyptus_globulus_0100.jpeg
# Renamed: Eucalyptus_globulus_0101.jpeg → Eucalyptus_globulus_0101.jpeg
# Renamed: Eucalyptus_globulus_0102.jpeg → Eucalyptus_globulus_0102.jpeg
# Renamed: Eucalyptus_globulus_0103.jpeg → Eucalyptus_globulus_0103.jpeg
# Renamed: Eucalyptus_globulus_0104.jpeg → Eucalyptus_globulus_0104.jpeg
# Renamed: Eucalyptus_globulus_0105.jpeg → Eucalyptus_globulus_0105.jpeg
# Renamed: Eucalyptus_globulus_0106.jpeg → Eucalyptus_globulus_0106.jpeg
# Renamed: Eucalyptus_globulus_0107.jpeg → Eucalyptus_globulus_0107.jpeg
# Renamed: Eucalyptus_globulus_0108.jpeg → Eucalyptus_globulus_0108.jpeg
# Renamed: Eucalyptus_globulus_0109.jpeg → Eucalyptus_globulus_0109.jpeg
# Renamed: Eucalyptus_globulus_0110.jpeg → Eucalyptus_globulus_0110.jpeg
# Renamed: Eucalyptus_globulus_0111.jpeg → Eucalyptus_globulus_0111.jpeg
# Renamed: Eucalyptus_globulus_0112.jpeg → Eucalyptus_globulus_0112.jpeg
# Renamed: Eucalyptus_globulus_0113.jpeg → Eucalyptus_globulus_0113.jpeg
# Renamed: Eucalyptus_globulus_0114.jpeg → Eucalyptus_globulus_0114.jpeg
# Renamed: Eucalyptus_globulus_0115.jpeg → Eucalyptus_globulus_0115.jpeg
# Renamed: Eucalyptus_globulus_0116.jpeg → Eucalyptus_globulus_0116.jpeg
# Renamed: Eucalyptus_globulus_0117.jpeg → Eucalyptus_globulus_0117.jpeg
# Renamed: Eucalyptus_globulus_0118.jpeg → Eucalyptus_globulus_0118.jpeg
# Renamed: Eucalyptus_globulus_0119.jpeg → Eucalyptus_globulus_0119.jpeg
# Renamed: Eucalyptus_globulus_0120.jpeg → Eucalyptus_globulus_0120.jpeg
# Renamed: Eucalyptus_globulus_0121.jpeg → Eucalyptus_globulus_0121.jpeg
# Renamed: Eucalyptus_globulus_0122.jpeg → Eucalyptus_globulus_0122.jpeg
# Renamed: Eucalyptus_globulus_0123.jpeg → Eucalyptus_globulus_0123.jpeg
# Renamed: Eucalyptus_globulus_0124.jpeg → Eucalyptus_globulus_0124.jpeg
# Renamed: Eucalyptus_globulus_0125.jpeg → Eucalyptus_globulus_0125.jpeg
# Renamed: Eucalyptus_globulus_0126.jpeg → Eucalyptus_globulus_0126.jpeg
# Renamed: Eucalyptus_globulus_0127.jpeg → Eucalyptus_globulus_0127.jpeg
# Renamed: Eucalyptus_globulus_0128.jpeg → Eucalyptus_globulus_0128.jpeg
# Renamed: Eucalyptus_globulus_0129.jpeg → Eucalyptus_globulus_0129.jpeg
# Renamed: Eucalyptus_globulus_0130.jpeg → Eucalyptus_globulus_0130.jpeg
# Renamed: Eucalyptus_globulus_0131.jpeg → Eucalyptus_globulus_0131.jpeg
# Renamed: Eucalyptus_globulus_0132.jpeg → Eucalyptus_globulus_0132.jpeg
# Renamed: Eucalyptus_globulus_0133.jpeg → Eucalyptus_globulus_0133.jpeg
# Renamed: Eucalyptus_globulus_0134.jpeg → Eucalyptus_globulus_0134.jpeg
# Renamed: Eucalyptus_globulus_0135.jpeg → Eucalyptus_globulus_0135.jpeg
# Renamed: Eucalyptus_globulus_0136.jpeg → Eucalyptus_globulus_0136.jpeg
# Renamed: Eucalyptus_globulus_0137.jpeg → Eucalyptus_globulus_0137.jpeg
# Renamed: Eucalyptus_globulus_0138.jpeg → Eucalyptus_globulus_0138.jpeg
# Renamed: Eucalyptus_globulus_0139.jpeg → Eucalyptus_globulus_0139.jpeg
# Renamed: Eucalyptus_globulus_0140.jpeg → Eucalyptus_globulus_0140.jpeg
# Renamed: Eucalyptus_globulus_0141.jpeg → Eucalyptus_globulus_0141.jpeg
# Renamed: Eucalyptus_globulus_0142.jpeg → Eucalyptus_globulus_0142.jpeg
# Renamed: Pinus_pinaster_0000.jpg → Pinus_pinaster_0000.jpg
# Renamed: Pinus_pinaster_0001.jpg → Pinus_pinaster_0001.jpg
# Renamed: Pinus_pinaster_0002.jpeg → Pinus_pinaster_0002.jpeg
# Renamed: Pinus_pinaster_0003.jpg → Pinus_pinaster_0003.jpg
# Renamed: Pinus_pinaster_0004.jpeg → Pinus_pinaster_0004.jpeg
# Renamed: Pinus_pinaster_0005.jpeg → Pinus_pinaster_0005.jpeg
# Renamed: Pinus_pinaster_0006.jpeg → Pinus_pinaster_0006.jpeg
# Renamed: Pinus_pinaster_0007.jpeg → Pinus_pinaster_0007.jpeg
# Renamed: Pinus_pinaster_0008.jpeg → Pinus_pinaster_0008.jpeg
# Renamed: Pinus_pinaster_0009.jpg → Pinus_pinaster_0009.jpg
# Renamed: Pinus_pinaster_0010.jpeg → Pinus_pinaster_0010.jpeg
# Renamed: Pinus_pinaster_0011.jpeg → Pinus_pinaster_0011.jpeg
# Renamed: Pinus_pinaster_0012.jpeg → Pinus_pinaster_0012.jpeg
# Renamed: Pinus_pinaster_0013.jpeg → Pinus_pinaster_0013.jpeg
# Renamed: Pinus_pinaster_0014.jpeg → Pinus_pinaster_0014.jpeg
# Renamed: Pinus_pinaster_0015.jpeg → Pinus_pinaster_0015.jpeg
# Renamed: Pinus_pinaster_0016.jpg → Pinus_pinaster_0016.jpg
# Renamed: Pinus_pinaster_0017.jpeg → Pinus_pinaster_0017.jpeg
# Renamed: Pinus_pinaster_0018.jpeg → Pinus_pinaster_0018.jpeg
# Renamed: Pinus_pinaster_0019.jpeg → Pinus_pinaster_0019.jpeg
# Renamed: Pinus_pinaster_0020.jpg → Pinus_pinaster_0020.jpg
# Renamed: Pinus_pinaster_0021.jpg → Pinus_pinaster_0021.jpg
# Renamed: Pinus_pinaster_0022.jpg → Pinus_pinaster_0022.jpg
# Renamed: Pinus_pinaster_0023.jpeg → Pinus_pinaster_0023.jpeg
# Renamed: Pinus_pinaster_0024.jpeg → Pinus_pinaster_0024.jpeg
# Renamed: Pinus_pinaster_0025.jpeg → Pinus_pinaster_0025.jpeg
# Renamed: Pinus_pinaster_0026.jpeg → Pinus_pinaster_0026.jpeg
# Renamed: Pinus_pinaster_0027.jpeg → Pinus_pinaster_0027.jpeg
# Renamed: Pinus_pinaster_0028.jpeg → Pinus_pinaster_0028.jpeg
# Renamed: Pinus_pinaster_0029.jpeg → Pinus_pinaster_0029.jpeg
# Renamed: Pinus_pinaster_0030.jpg → Pinus_pinaster_0030.jpg
# Renamed: Pinus_pinaster_0031.jpg → Pinus_pinaster_0031.jpg
# Renamed: Pinus_pinaster_0032.jpg → Pinus_pinaster_0032.jpg
# Renamed: Pinus_pinaster_0033.jpg → Pinus_pinaster_0033.jpg
# Renamed: Pinus_pinaster_0034.jpeg → Pinus_pinaster_0034.jpeg
# Renamed: Pinus_pinaster_0035.jpg → Pinus_pinaster_0035.jpg
# Renamed: Pinus_pinaster_0036.jpeg → Pinus_pinaster_0036.jpeg
# Renamed: Pinus_pinaster_0037.jpg → Pinus_pinaster_0037.jpg
# Renamed: Pinus_pinaster_0038.jpeg → Pinus_pinaster_0038.jpeg
# Renamed: Pinus_pinaster_0039.jpg → Pinus_pinaster_0039.jpg
# Renamed: Pinus_pinaster_0040.jpeg → Pinus_pinaster_0040.jpeg
# Renamed: Pinus_pinaster_0041.jpg → Pinus_pinaster_0041.jpg
# Renamed: Pinus_pinaster_0042.jpeg → Pinus_pinaster_0042.jpeg
# Renamed: Pinus_pinaster_0043.jpeg → Pinus_pinaster_0043.jpeg
# Renamed: Pinus_pinaster_0044.jpeg → Pinus_pinaster_0044.jpeg
# Renamed: Pinus_pinaster_0045.jpg → Pinus_pinaster_0045.jpg
# Renamed: Pinus_pinaster_0046.jpeg → Pinus_pinaster_0046.jpeg
# Renamed: Pinus_pinaster_0047.jpg → Pinus_pinaster_0047.jpg
# Renamed: Pinus_pinaster_0048.jpeg → Pinus_pinaster_0048.jpeg
# Renamed: Pinus_pinaster_0049.jpeg → Pinus_pinaster_0049.jpeg
# Renamed: Pinus_pinaster_0050.jpg → Pinus_pinaster_0050.jpg
# Renamed: Pinus_pinaster_0051.jpeg → Pinus_pinaster_0051.jpeg
# Renamed: Pinus_pinaster_0052.jpg → Pinus_pinaster_0052.jpg
# Renamed: Pinus_pinaster_0053.jpeg → Pinus_pinaster_0053.jpeg
# Renamed: Pinus_pinaster_0054.jpeg → Pinus_pinaster_0054.jpeg
# Renamed: Pinus_pinaster_0055.jpeg → Pinus_pinaster_0055.jpeg
# Renamed: Pinus_pinaster_0056.jpeg → Pinus_pinaster_0056.jpeg
# Renamed: Pinus_pinaster_0057.jpg → Pinus_pinaster_0057.jpg
# Renamed: Pinus_pinaster_0058.jpeg → Pinus_pinaster_0058.jpeg
# Renamed: Pinus_pinaster_0059.jpg → Pinus_pinaster_0059.jpg
# Renamed: Pinus_pinaster_0060.jpeg → Pinus_pinaster_0060.jpeg
# Renamed: Pinus_pinaster_0061.jpeg → Pinus_pinaster_0061.jpeg
# Renamed: Pinus_pinaster_0062.jpeg → Pinus_pinaster_0062.jpeg
# Renamed: Pinus_pinaster_0063.jpeg → Pinus_pinaster_0063.jpeg
# Renamed: Pinus_pinaster_0064.jpeg → Pinus_pinaster_0064.jpeg
# Renamed: Pinus_pinaster_0065.jpeg → Pinus_pinaster_0065.jpeg
# Renamed: Pinus_pinaster_0066.jpeg → Pinus_pinaster_0066.jpeg
# Renamed: Pinus_pinaster_0067.jpeg → Pinus_pinaster_0067.jpeg
# Renamed: Pinus_pinaster_0068.jpeg → Pinus_pinaster_0068.jpeg
# Renamed: Pinus_pinaster_0069.jpeg → Pinus_pinaster_0069.jpeg
# Renamed: Pinus_pinaster_0070.jpeg → Pinus_pinaster_0070.jpeg
# Renamed: Pinus_pinaster_0071.jpeg → Pinus_pinaster_0071.jpeg
# Renamed: Pinus_pinaster_0072.jpeg → Pinus_pinaster_0072.jpeg
# Renamed: Pinus_pinaster_0073.jpeg → Pinus_pinaster_0073.jpeg
# Renamed: Pinus_pinaster_0074.jpg → Pinus_pinaster_0074.jpg
# Renamed: Pinus_pinaster_0075.jpg → Pinus_pinaster_0075.jpg
# Renamed: Pinus_pinaster_0076.jpg → Pinus_pinaster_0076.jpg
# Renamed: Pinus_pinaster_0077.jpg → Pinus_pinaster_0077.jpg
# Renamed: Pinus_pinaster_0078.jpeg → Pinus_pinaster_0078.jpeg
# Renamed: Pinus_pinaster_0079.jpeg → Pinus_pinaster_0079.jpeg
# Renamed: Pinus_pinaster_0080.jpeg → Pinus_pinaster_0080.jpeg
# Renamed: Pinus_pinaster_0081.jpeg → Pinus_pinaster_0081.jpeg
# Renamed: Pinus_pinaster_0082.jpeg → Pinus_pinaster_0082.jpeg
# Renamed: Pinus_pinaster_0083.jpeg → Pinus_pinaster_0083.jpeg
# Renamed: Pinus_pinaster_0084.jpeg → Pinus_pinaster_0084.jpeg
# Renamed: Pinus_pinaster_0085.jpeg → Pinus_pinaster_0085.jpeg
# Renamed: Pinus_pinaster_0086.jpeg → Pinus_pinaster_0086.jpeg
# Renamed: Pinus_pinaster_0087.jpeg → Pinus_pinaster_0087.jpeg
# Renamed: Pinus_pinaster_0088.jpeg → Pinus_pinaster_0088.jpeg
# Renamed: Pinus_pinaster_0089.jpeg → Pinus_pinaster_0089.jpeg
# Renamed: Pinus_pinaster_0090.jpeg → Pinus_pinaster_0090.jpeg
# Renamed: Pinus_pinaster_0091.jpeg → Pinus_pinaster_0091.jpeg
# Renamed: Pinus_pinaster_0092.jpeg → Pinus_pinaster_0092.jpeg
# Renamed: Pinus_pinaster_0093.jpeg → Pinus_pinaster_0093.jpeg
# Renamed: Pinus_pinaster_0094.jpeg → Pinus_pinaster_0094.jpeg
# Renamed: Pinus_pinaster_0095.jpeg → Pinus_pinaster_0095.jpeg
# Renamed: Pinus_pinaster_0096.jpeg → Pinus_pinaster_0096.jpeg
# Renamed: Pinus_pinaster_0097.jpeg → Pinus_pinaster_0097.jpeg
# Renamed: Pinus_pinaster_0098.jpeg → Pinus_pinaster_0098.jpeg
# Renamed: Pinus_pinaster_0099.jpeg → Pinus_pinaster_0099.jpeg
# Renamed: Pinus_pinaster_0100.jpeg → Pinus_pinaster_0100.jpeg
# Renamed: Pinus_pinaster_0101.jpeg → Pinus_pinaster_0101.jpeg
# Renamed: Pinus_pinaster_0102.jpeg → Pinus_pinaster_0102.jpeg
# Renamed: Pinus_pinaster_0103.jpeg → Pinus_pinaster_0103.jpeg
# Renamed: Pinus_pinaster_0104.jpeg → Pinus_pinaster_0104.jpeg
# Renamed: Pinus_pinaster_0105.jpeg → Pinus_pinaster_0105.jpeg
# Renamed: Pinus_pinaster_0106.jpeg → Pinus_pinaster_0106.jpeg
# Renamed: Pinus_pinaster_0107.jpeg → Pinus_pinaster_0107.jpeg
# Renamed: Pinus_pinaster_0108.jpeg → Pinus_pinaster_0108.jpeg
# Renamed: Pinus_pinaster_0109.jpeg → Pinus_pinaster_0109.jpeg
# Renamed: Pinus_pinaster_0110.jpeg → Pinus_pinaster_0110.jpeg
# Renamed: Pinus_pinaster_0111.jpeg → Pinus_pinaster_0111.jpeg
# Renamed: Pinus_pinaster_0112.jpeg → Pinus_pinaster_0112.jpeg
# Renamed: Pinus_pinaster_0113.jpeg → Pinus_pinaster_0113.jpeg
# Renamed: Pinus_pinaster_0114.jpeg → Pinus_pinaster_0114.jpeg
# Renamed: Pinus_pinaster_0115.jpeg → Pinus_pinaster_0115.jpeg
# Renamed: Pinus_pinaster_0116.jpeg → Pinus_pinaster_0116.jpeg
# Renamed: Pinus_pinaster_0117.jpeg → Pinus_pinaster_0117.jpeg
# Renamed: Pinus_pinaster_0118.jpeg → Pinus_pinaster_0118.jpeg
# Renamed: Pinus_pinaster_0119.jpeg → Pinus_pinaster_0119.jpeg
# Renamed: Pinus_pinaster_0120.jpeg → Pinus_pinaster_0120.jpeg
# Renamed: Pinus_pinaster_0121.jpeg → Pinus_pinaster_0121.jpeg
# Renamed: Pinus_pinaster_0122.jpeg → Pinus_pinaster_0122.jpeg
# Renamed: Pinus_pinaster_0123.jpeg → Pinus_pinaster_0123.jpeg
# Renamed: Pinus_pinaster_0124.jpeg → Pinus_pinaster_0124.jpeg
# Renamed: Pinus_pinaster_0125.jpeg → Pinus_pinaster_0125.jpeg
# Renamed: Pinus_pinaster_0126.jpeg → Pinus_pinaster_0126.jpeg
# Renamed: Pinus_pinaster_0127.jpeg → Pinus_pinaster_0127.jpeg
# Renamed: Pinus_pinaster_0128.jpeg → Pinus_pinaster_0128.jpeg
# Renamed: Pinus_pinaster_0129.jpeg → Pinus_pinaster_0129.jpeg
# Renamed: Pinus_pinaster_0130.jpeg → Pinus_pinaster_0130.jpeg
# Renamed: Pinus_pinaster_0131.jpeg → Pinus_pinaster_0131.jpeg
# Renamed: Pinus_pinaster_0132.jpeg → Pinus_pinaster_0132.jpeg
# Renamed: Pinus_pinaster_0133.jpeg → Pinus_pinaster_0133.jpeg
# Renamed: Pinus_pinaster_0134.jpg → Pinus_pinaster_0134.jpg
# Renamed: Pinus_pinaster_0135.jpeg → Pinus_pinaster_0135.jpeg
# Renamed: Pinus_pinaster_0136.jpeg → Pinus_pinaster_0136.jpeg
# Renamed: Pinus_pinaster_0137.jpg → Pinus_pinaster_0137.jpg
# Renamed: Pinus_pinaster_0138.jpeg → Pinus_pinaster_0138.jpeg
# Renamed: Pinus_pinaster_0139.jpeg → Pinus_pinaster_0139.jpeg
# Renamed: Pinus_pinaster_0140.jpeg → Pinus_pinaster_0140.jpeg
# Renamed: Pinus_pinaster_0141.jpeg → Pinus_pinaster_0141.jpeg
# Renamed: Pinus_pinaster_0142.jpeg → Pinus_pinaster_0142.jpeg
# Renamed: Pinus_pinaster_0143.jpeg → Pinus_pinaster_0143.jpeg
# Renamed: Pinus_pinaster_0144.jpeg → Pinus_pinaster_0144.jpeg
# Renamed: Pinus_pinaster_0145.jpeg → Pinus_pinaster_0145.jpeg
# Renamed: Pinus_pinaster_0146.jpeg → Pinus_pinaster_0146.jpeg
# Renamed: Pinus_pinaster_0147.jpeg → Pinus_pinaster_0147.jpeg
# Renamed: Pinus_pinaster_0148.jpeg → Pinus_pinaster_0148.jpeg
# Renamed: Pinus_pinaster_0149.jpeg → Pinus_pinaster_0149.jpeg
# Renamed: Pinus_pinaster_0150.jpeg → Pinus_pinaster_0150.jpeg
# Renamed: Pinus_pinaster_0151.jpeg → Pinus_pinaster_0151.jpeg
# Renamed: Pinus_pinaster_0152.jpeg → Pinus_pinaster_0152.jpeg
# Renamed: Pinus_pinaster_0153.jpeg → Pinus_pinaster_0153.jpeg
# Renamed: Pinus_pinaster_0154.jpeg → Pinus_pinaster_0154.jpeg
# Renamed: Pinus_pinaster_0155.jpeg → Pinus_pinaster_0155.jpeg
# Renamed: Pinus_pinaster_0156.jpeg → Pinus_pinaster_0156.jpeg
# Renamed: Pinus_pinaster_0157.jpeg → Pinus_pinaster_0157.jpeg
# Renamed: Pinus_pinaster_0158.jpg → Pinus_pinaster_0158.jpg
# Renamed: Pinus_pinaster_0159.jpeg → Pinus_pinaster_0159.jpeg
# Renamed: Pinus_pinaster_0160.jpeg → Pinus_pinaster_0160.jpeg
# Renamed: Pinus_pinaster_0161.jpeg → Pinus_pinaster_0161.jpeg
# Renamed: Pinus_pinaster_0162.jpeg → Pinus_pinaster_0162.jpeg
# Renamed: Pinus_pinaster_0163.jpeg → Pinus_pinaster_0163.jpeg
# Renamed: Pinus_pinaster_0164.jpeg → Pinus_pinaster_0164.jpeg
# Renamed: Pinus_pinaster_0165.jpeg → Pinus_pinaster_0165.jpeg
# Renamed: Pinus_pinaster_0166.jpeg → Pinus_pinaster_0166.jpeg
# Renamed: Pinus_pinaster_0167.jpeg → Pinus_pinaster_0167.jpeg
# Renamed: Pinus_pinaster_0168.jpg → Pinus_pinaster_0168.jpg
# Renamed: Pinus_pinaster_0169.jpeg → Pinus_pinaster_0169.jpeg
# Renamed: Pinus_pinaster_0170.jpeg → Pinus_pinaster_0170.jpeg
# Renamed: Pinus_pinaster_0171.jpeg → Pinus_pinaster_0171.jpeg
# Renamed: Pinus_pinaster_0172.jpeg → Pinus_pinaster_0172.jpeg
# Renamed: Pinus_pinaster_0173.jpeg → Pinus_pinaster_0173.jpeg
# Renamed: Pinus_pinaster_0174.jpeg → Pinus_pinaster_0174.jpeg
# Renamed: Pinus_pinaster_0175.jpeg → Pinus_pinaster_0175.jpeg
# Renamed: Pinus_pinaster_0176.jpeg → Pinus_pinaster_0176.jpeg
# Renamed: Pinus_pinaster_0177.jpeg → Pinus_pinaster_0177.jpeg
# Renamed: Pinus_pinaster_0178.jpeg → Pinus_pinaster_0178.jpeg
# Renamed: Pinus_pinaster_0179.jpeg → Pinus_pinaster_0179.jpeg
# Renamed: Pinus_pinaster_0180.jpeg → Pinus_pinaster_0180.jpeg
# Renamed: Pinus_pinaster_0181.jpeg → Pinus_pinaster_0181.jpeg
# Renamed: Pinus_pinaster_0182.jpeg → Pinus_pinaster_0182.jpeg
# Renamed: Pinus_pinaster_0183.jpeg → Pinus_pinaster_0183.jpeg
# Renamed: Pinus_pinaster_0184.jpeg → Pinus_pinaster_0184.jpeg
# Renamed: Pinus_pinaster_0185.jpeg → Pinus_pinaster_0185.jpeg
# Renamed: Pinus_pinaster_0186.jpeg → Pinus_pinaster_0186.jpeg
# Renamed: Pinus_pinaster_0187.jpeg → Pinus_pinaster_0187.jpeg
# Renamed: Pinus_pinaster_0188.jpeg → Pinus_pinaster_0188.jpeg
# Renamed: Pinus_pinaster_0189.jpeg → Pinus_pinaster_0189.jpeg
# Renamed: Pinus_pinaster_0190.jpeg → Pinus_pinaster_0190.jpeg
# Renamed: Pinus_pinaster_0191.jpeg → Pinus_pinaster_0191.jpeg
# Renamed: Pinus_pinaster_0192.jpeg → Pinus_pinaster_0192.jpeg
# Renamed: Pinus_pinaster_0193.jpeg → Pinus_pinaster_0193.jpeg
# Renamed: Pinus_pinaster_0194.jpeg → Pinus_pinaster_0194.jpeg
# Renamed: Pinus_pinaster_0195.jpeg → Pinus_pinaster_0195.jpeg
# Renamed: Pinus_pinaster_0196.jpg → Pinus_pinaster_0196.jpg
# Renamed: Pinus_pinaster_0197.jpeg → Pinus_pinaster_0197.jpeg
# Renamed: Pinus_pinaster_0198.JPG → Pinus_pinaster_0198.JPG
# Renamed: Pinus_pinaster_0199.JPG → Pinus_pinaster_0199.JPG
# Renamed: Pinus_pinaster_0200.jpeg → Pinus_pinaster_0200.jpeg
# Renamed: Pinus_pinaster_0201.jpeg → Pinus_pinaster_0201.jpeg
# Renamed: Pinus_pinaster_0202.jpg → Pinus_pinaster_0202.jpg
# Renamed: Pinus_pinaster_0203.JPG → Pinus_pinaster_0203.JPG
# Renamed: Pinus_pinaster_0204.JPG → Pinus_pinaster_0204.JPG
# Renamed: Pinus_pinaster_0205.JPG → Pinus_pinaster_0205.JPG
# Renamed: Pinus_pinaster_0206.JPG → Pinus_pinaster_0206.JPG
# Renamed: Pinus_pinaster_0207.jpg → Pinus_pinaster_0207.jpg
# Renamed: Pinus_pinaster_0208.JPG → Pinus_pinaster_0208.JPG
# Renamed: Pinus_pinaster_0209.JPG → Pinus_pinaster_0209.JPG
# Renamed: Pinus_pinaster_0210.JPG → Pinus_pinaster_0210.JPG
# Renamed: Pinus_pinaster_0211.JPG → Pinus_pinaster_0211.JPG
# Renamed: Pinus_pinaster_0212.JPG → Pinus_pinaster_0212.JPG
# Renamed: Pinus_pinaster_0213.JPG → Pinus_pinaster_0213.JPG
# Renamed: Pinus_pinaster_0214.JPG → Pinus_pinaster_0214.JPG
# Renamed: Pinus_pinaster_0215.JPG → Pinus_pinaster_0215.JPG
# Renamed: Pinus_pinaster_0216.jpeg → Pinus_pinaster_0216.jpeg
# Renamed: Quercus_suber_0000.jpeg → Quercus_suber_0000.jpeg
# Renamed: Quercus_suber_0001.jpeg → Quercus_suber_0001.jpeg
# Renamed: Quercus_suber_0002.jpg → Quercus_suber_0002.jpg
# Renamed: Quercus_suber_0003.jpeg → Quercus_suber_0003.jpeg
# Renamed: Quercus_suber_0004.jpeg → Quercus_suber_0004.jpeg
# Renamed: Quercus_suber_0005.jpeg → Quercus_suber_0005.jpeg
# Renamed: Quercus_suber_0006.jpeg → Quercus_suber_0006.jpeg
# Renamed: Quercus_suber_0007.jpeg → Quercus_suber_0007.jpeg
# Renamed: Quercus_suber_0008.jpeg → Quercus_suber_0008.jpeg
# Renamed: Quercus_suber_0009.jpeg → Quercus_suber_0009.jpeg
# Renamed: Quercus_suber_0010.jpeg → Quercus_suber_0010.jpeg
# Renamed: Quercus_suber_0011.jpeg → Quercus_suber_0011.jpeg
# Renamed: Quercus_suber_0012.jpg → Quercus_suber_0012.jpg
# Renamed: Quercus_suber_0013.jpeg → Quercus_suber_0013.jpeg
# Renamed: Quercus_suber_0014.jpeg → Quercus_suber_0014.jpeg
# Renamed: Quercus_suber_0015.jpeg → Quercus_suber_0015.jpeg
# Renamed: Quercus_suber_0016.jpg → Quercus_suber_0016.jpg
# Renamed: Quercus_suber_0017.jpeg → Quercus_suber_0017.jpeg
# Renamed: Quercus_suber_0018.jpeg → Quercus_suber_0018.jpeg
# Renamed: Quercus_suber_0019.jpg → Quercus_suber_0019.jpg
# Renamed: Quercus_suber_0020.jpg → Quercus_suber_0020.jpg
# Renamed: Quercus_suber_0021.jpeg → Quercus_suber_0021.jpeg
# Renamed: Quercus_suber_0022.jpeg → Quercus_suber_0022.jpeg
# Renamed: Quercus_suber_0023.jpeg → Quercus_suber_0023.jpeg
# Renamed: Quercus_suber_0024.jpeg → Quercus_suber_0024.jpeg
# Renamed: Quercus_suber_0025.jpeg → Quercus_suber_0025.jpeg
# Renamed: Quercus_suber_0026.jpeg → Quercus_suber_0026.jpeg
# Renamed: Quercus_suber_0027.jpeg → Quercus_suber_0027.jpeg
# Renamed: Quercus_suber_0028.jpg → Quercus_suber_0028.jpg
# Renamed: Quercus_suber_0029.jpeg → Quercus_suber_0029.jpeg
# Renamed: Quercus_suber_0030.jpg → Quercus_suber_0030.jpg
# Renamed: Quercus_suber_0031.jpeg → Quercus_suber_0031.jpeg
# Renamed: Quercus_suber_0032.jpeg → Quercus_suber_0032.jpeg
# Renamed: Quercus_suber_0033.jpg → Quercus_suber_0033.jpg
# Renamed: Quercus_suber_0034.jpeg → Quercus_suber_0034.jpeg
# Renamed: Quercus_suber_0035.jpg → Quercus_suber_0035.jpg
# Renamed: Quercus_suber_0036.jpg → Quercus_suber_0036.jpg
# Renamed: Quercus_suber_0037.jpg → Quercus_suber_0037.jpg
# Renamed: Quercus_suber_0038.jpeg → Quercus_suber_0038.jpeg
# Renamed: Quercus_suber_0039.jpeg → Quercus_suber_0039.jpeg
# Renamed: Quercus_suber_0040.jpeg → Quercus_suber_0040.jpeg
# Renamed: Quercus_suber_0041.jpeg → Quercus_suber_0041.jpeg
# Renamed: Quercus_suber_0042.jpeg → Quercus_suber_0042.jpeg
# Renamed: Quercus_suber_0043.jpeg → Quercus_suber_0043.jpeg
# Renamed: Quercus_suber_0044.jpg → Quercus_suber_0044.jpg
# Renamed: Quercus_suber_0045.jpeg → Quercus_suber_0045.jpeg
# Renamed: Quercus_suber_0046.jpg → Quercus_suber_0046.jpg
# Renamed: Quercus_suber_0047.jpg → Quercus_suber_0047.jpg
# Renamed: Quercus_suber_0048.jpeg → Quercus_suber_0048.jpeg
# Renamed: Quercus_suber_0049.jpeg → Quercus_suber_0049.jpeg
# Renamed: Quercus_suber_0050.jpeg → Quercus_suber_0050.jpeg
# Renamed: Quercus_suber_0051.jpg → Quercus_suber_0051.jpg
# Renamed: Quercus_suber_0052.jpeg → Quercus_suber_0052.jpeg
# Renamed: Quercus_suber_0053.jpg → Quercus_suber_0053.jpg
# Renamed: Quercus_suber_0054.jpg → Quercus_suber_0054.jpg
# Renamed: Quercus_suber_0055.jpg → Quercus_suber_0055.jpg
# Renamed: Quercus_suber_0056.jpg → Quercus_suber_0056.jpg
# Renamed: Quercus_suber_0057.jpg → Quercus_suber_0057.jpg
# Renamed: Quercus_suber_0058.jpeg → Quercus_suber_0058.jpeg
# Renamed: Quercus_suber_0059.jpeg → Quercus_suber_0059.jpeg
# Renamed: Quercus_suber_0060.jpeg → Quercus_suber_0060.jpeg
# Renamed: Quercus_suber_0061.jpeg → Quercus_suber_0061.jpeg
# Renamed: Quercus_suber_0062.jpeg → Quercus_suber_0062.jpeg
# Renamed: Quercus_suber_0063.jpeg → Quercus_suber_0063.jpeg
# Renamed: Quercus_suber_0064.jpeg → Quercus_suber_0064.jpeg
# Renamed: Quercus_suber_0065.jpeg → Quercus_suber_0065.jpeg
# Renamed: Quercus_suber_0066.jpeg → Quercus_suber_0066.jpeg
# Renamed: Quercus_suber_0067.jpeg → Quercus_suber_0067.jpeg
# Renamed: Quercus_suber_0068.jpeg → Quercus_suber_0068.jpeg
# Renamed: Quercus_suber_0069.jpeg → Quercus_suber_0069.jpeg
# Renamed: Quercus_suber_0070.jpeg → Quercus_suber_0070.jpeg
# Renamed: Quercus_suber_0071.jpeg → Quercus_suber_0071.jpeg
# Renamed: Quercus_suber_0072.jpeg → Quercus_suber_0072.jpeg
# Renamed: Quercus_suber_0073.jpeg → Quercus_suber_0073.jpeg
# Renamed: Quercus_suber_0074.jpeg → Quercus_suber_0074.jpeg
# Renamed: Quercus_suber_0075.jpeg → Quercus_suber_0075.jpeg
# Renamed: Quercus_suber_0076.jpg → Quercus_suber_0076.jpg
# Renamed: Quercus_suber_0077.jpeg → Quercus_suber_0077.jpeg
# Renamed: Quercus_suber_0078.jpeg → Quercus_suber_0078.jpeg
# Renamed: Quercus_suber_0079.jpeg → Quercus_suber_0079.jpeg
# Renamed: Quercus_suber_0080.jpeg → Quercus_suber_0080.jpeg
# Renamed: Quercus_suber_0081.jpeg → Quercus_suber_0081.jpeg
# Renamed: Quercus_suber_0082.jpeg → Quercus_suber_0082.jpeg
# Renamed: Quercus_suber_0083.jpeg → Quercus_suber_0083.jpeg
# Renamed: Quercus_suber_0084.jpeg → Quercus_suber_0084.jpeg
# Renamed: Quercus_suber_0085.jpeg → Quercus_suber_0085.jpeg
# Renamed: Quercus_suber_0086.jpeg → Quercus_suber_0086.jpeg
# Renamed: Quercus_suber_0087.jpeg → Quercus_suber_0087.jpeg
# Renamed: Quercus_suber_0088.jpeg → Quercus_suber_0088.jpeg
# Renamed: Quercus_suber_0089.jpeg → Quercus_suber_0089.jpeg
# Renamed: Quercus_suber_0090.jpg → Quercus_suber_0090.jpg
# Renamed: Quercus_suber_0091.jpeg → Quercus_suber_0091.jpeg
# Renamed: Quercus_suber_0092.jpeg → Quercus_suber_0092.jpeg
# Renamed: Quercus_suber_0093.jpeg → Quercus_suber_0093.jpeg
# Renamed: Quercus_suber_0094.jpeg → Quercus_suber_0094.jpeg
# Renamed: Quercus_suber_0095.jpeg → Quercus_suber_0095.jpeg
# Renamed: Quercus_suber_0096.jpeg → Quercus_suber_0096.jpeg
# Renamed: Quercus_suber_0097.jpeg → Quercus_suber_0097.jpeg
# Renamed: Quercus_suber_0098.jpeg → Quercus_suber_0098.jpeg
# Renamed: Quercus_suber_0099.jpeg → Quercus_suber_0099.jpeg
# Renamed: Quercus_suber_0100.jpeg → Quercus_suber_0100.jpeg
# Renamed: Quercus_suber_0101.jpeg → Quercus_suber_0101.jpeg
# Renamed: Quercus_suber_0102.jpeg → Quercus_suber_0102.jpeg
# Renamed: Quercus_suber_0103.jpeg → Quercus_suber_0103.jpeg
# Renamed: Quercus_suber_0104.jpeg → Quercus_suber_0104.jpeg
# Renamed: Quercus_suber_0105.jpeg → Quercus_suber_0105.jpeg
# Renamed: Quercus_suber_0106.jpeg → Quercus_suber_0106.jpeg
# Renamed: Quercus_suber_0107.jpeg → Quercus_suber_0107.jpeg
# Renamed: Quercus_suber_0108.jpeg → Quercus_suber_0108.jpeg
# Renamed: Quercus_suber_0109.jpeg → Quercus_suber_0109.jpeg
# Renamed: Quercus_suber_0110.jpg → Quercus_suber_0110.jpg
# Renamed: Quercus_suber_0111.jpeg → Quercus_suber_0111.jpeg
# Renamed: Quercus_suber_0112.jpeg → Quercus_suber_0112.jpeg
# Renamed: Quercus_suber_0113.jpeg → Quercus_suber_0113.jpeg
# Renamed: Quercus_suber_0114.jpeg → Quercus_suber_0114.jpeg
# Renamed: Quercus_suber_0115.jpeg → Quercus_suber_0115.jpeg
# Renamed: Quercus_suber_0116.jpeg → Quercus_suber_0116.jpeg
# Renamed: Quercus_suber_0117.jpeg → Quercus_suber_0117.jpeg
# Renamed: Quercus_suber_0118.jpeg → Quercus_suber_0118.jpeg
# Renamed: Quercus_suber_0119.jpeg → Quercus_suber_0119.jpeg
# Renamed: Quercus_suber_0120.jpeg → Quercus_suber_0120.jpeg
# Renamed: Quercus_suber_0121.jpeg → Quercus_suber_0121.jpeg
# Renamed: Quercus_suber_0122.jpeg → Quercus_suber_0122.jpeg
# Renamed: Quercus_suber_0123.jpeg → Quercus_suber_0123.jpeg
# Renamed: Quercus_suber_0124.jpeg → Quercus_suber_0124.jpeg
# Renamed: Quercus_suber_0125.jpeg → Quercus_suber_0125.jpeg
# Renamed: Quercus_suber_0126.jpg → Quercus_suber_0126.jpg
# Renamed: Quercus_suber_0127.jpeg → Quercus_suber_0127.jpeg
# Renamed: Quercus_suber_0128.jpeg → Quercus_suber_0128.jpeg
# Renamed: Quercus_suber_0129.jpeg → Quercus_suber_0129.jpeg
# Renamed: Quercus_suber_0130.jpeg → Quercus_suber_0130.jpeg
# Renamed: Quercus_suber_0131.jpeg → Quercus_suber_0131.jpeg
# Renamed: Quercus_suber_0132.jpg → Quercus_suber_0132.jpg
# Renamed: Quercus_suber_0133.jpeg → Quercus_suber_0133.jpeg
# Renamed: Quercus_suber_0134.jpeg → Quercus_suber_0134.jpeg
# Renamed: Quercus_suber_0135.jpeg → Quercus_suber_0135.jpeg
# Renamed: Quercus_suber_0136.jpeg → Quercus_suber_0136.jpeg
# Renamed: Quercus_suber_0137.jpeg → Quercus_suber_0137.jpeg
# Renamed: Quercus_suber_0138.jpeg → Quercus_suber_0138.jpeg
# Renamed: Quercus_suber_0139.jpeg → Quercus_suber_0139.jpeg
# Renamed: Quercus_suber_0140.jpeg → Quercus_suber_0140.jpeg
# Renamed: Quercus_suber_0141.jpeg → Quercus_suber_0141.jpeg
# Renamed: Quercus_suber_0142.jpeg → Quercus_suber_0142.jpeg
# Renamed: Quercus_suber_0143.jpeg → Quercus_suber_0143.jpeg
# Renamed: Quercus_suber_0144.jpeg → Quercus_suber_0144.jpeg
# Renamed: Quercus_suber_0145.jpeg → Quercus_suber_0145.jpeg
# Renamed: Quercus_suber_0146.jpeg → Quercus_suber_0146.jpeg
# Renamed: Quercus_suber_0147.jpeg → Quercus_suber_0147.jpeg
# Renamed: Quercus_suber_0148.jpeg → Quercus_suber_0148.jpeg
# Renamed: Quercus_suber_0149.jpeg → Quercus_suber_0149.jpeg
# Renamed: Quercus_suber_0150.jpeg → Quercus_suber_0150.jpeg
# Renamed: Quercus_suber_0151.jpeg → Quercus_suber_0151.jpeg
# Renamed: Quercus_suber_0152.jpeg → Quercus_suber_0152.jpeg
# Renamed: Quercus_suber_0153.jpeg → Quercus_suber_0153.jpeg
# Renamed: Quercus_suber_0154.jpeg → Quercus_suber_0154.jpeg
# Renamed: Quercus_suber_0155.jpeg → Quercus_suber_0155.jpeg
# Renamed: Quercus_suber_0156.jpeg → Quercus_suber_0156.jpeg
# Renamed: Quercus_suber_0157.jpeg → Quercus_suber_0157.jpeg
# Renamed: Quercus_suber_0158.jpeg → Quercus_suber_0158.jpeg
# Renamed: Quercus_suber_0159.jpeg → Quercus_suber_0159.jpeg
# Renamed: Quercus_suber_0160.jpeg → Quercus_suber_0160.jpeg
# Renamed: Quercus_suber_0161.jpeg → Quercus_suber_0161.jpeg
# Renamed: Quercus_suber_0162.jpeg → Quercus_suber_0162.jpeg
# Renamed: Quercus_suber_0163.jpeg → Quercus_suber_0163.jpeg
# Renamed: Quercus_suber_0164.jpeg → Quercus_suber_0164.jpeg
# Renamed: Quercus_suber_0165.jpeg → Quercus_suber_0165.jpeg
# Renamed: Quercus_suber_0166.jpeg → Quercus_suber_0166.jpeg
# Renamed: Quercus_suber_0167.jpeg → Quercus_suber_0167.jpeg
# Renamed: Quercus_suber_0168.jpeg → Quercus_suber_0168.jpeg
# Renamed: Quercus_suber_0169.jpeg → Quercus_suber_0169.jpeg
# Renamed: Quercus_suber_0170.jpeg → Quercus_suber_0170.jpeg
# Renamed: Quercus_suber_0171.jpeg → Quercus_suber_0171.jpeg
# Renamed: Quercus_suber_0172.jpeg → Quercus_suber_0172.jpeg
# Renamed: Quercus_suber_0173.jpeg → Quercus_suber_0173.jpeg
# Renamed: Quercus_suber_0174.jpeg → Quercus_suber_0174.jpeg
# Renamed: Quercus_suber_0175.jpeg → Quercus_suber_0175.jpeg
# Renamed: Quercus_suber_0176.jpeg → Quercus_suber_0176.jpeg
# Renamed: Quercus_suber_0177.jpeg → Quercus_suber_0177.jpeg
# Renamed: Quercus_suber_0178.jpeg → Quercus_suber_0178.jpeg
# Renamed: Quercus_suber_0179.jpeg → Quercus_suber_0179.jpeg
# Renamed: Quercus_suber_0180.jpeg → Quercus_suber_0180.jpeg
# Renamed: Quercus_suber_0181.jpeg → Quercus_suber_0181.jpeg
# Renamed: Quercus_suber_0182.jpeg → Quercus_suber_0182.jpeg
# Renamed: Quercus_suber_0183.jpeg → Quercus_suber_0183.jpeg
# Renamed: Quercus_suber_0184.jpeg → Quercus_suber_0184.jpeg
# Renamed: Quercus_suber_0185.jpg → Quercus_suber_0185.jpg
# Renamed: Quercus_suber_0186.jpeg → Quercus_suber_0186.jpeg
# Renamed: Quercus_suber_0187.jpeg → Quercus_suber_0187.jpeg
# Renamed: Quercus_suber_0188.jpeg → Quercus_suber_0188.jpeg
# Renamed: Quercus_suber_0189.jpeg → Quercus_suber_0189.jpeg
# Renamed: Quercus_suber_0190.jpeg → Quercus_suber_0190.jpeg
# Renamed: Quercus_suber_0191.jpeg → Quercus_suber_0191.jpeg
# Renamed: Quercus_suber_0192.jpeg → Quercus_suber_0192.jpeg
# Renamed: Quercus_suber_0193.jpeg → Quercus_suber_0193.jpeg
# Renamed: Quercus_suber_0194.jpeg → Quercus_suber_0194.jpeg
# Renamed: Quercus_suber_0195.jpeg → Quercus_suber_0195.jpeg
# Renamed: Quercus_suber_0196.jpeg → Quercus_suber_0196.jpeg
# Renamed: Quercus_suber_0197.jpeg → Quercus_suber_0197.jpeg
# Renamed: Quercus_suber_0198.jpeg → Quercus_suber_0198.jpeg
# Renamed: Quercus_suber_0199.jpg → Quercus_suber_0199.jpg
# Renamed: Quercus_suber_0200.jpg → Quercus_suber_0200.jpg
# Renamed: Quercus_suber_0201.jpg → Quercus_suber_0201.jpg
# Renamed: Quercus_suber_0202.jpeg → Quercus_suber_0202.jpeg
# Renamed: Quercus_suber_0203.jpeg → Quercus_suber_0203.jpeg
# Renamed: Quercus_suber_0204.jpeg → Quercus_suber_0204.jpeg
# Renamed: Quercus_suber_0205.jpeg → Quercus_suber_0205.jpeg
# Renamed: Quercus_suber_0206.jpeg → Quercus_suber_0206.jpeg
# Renamed: Quercus_suber_0207.jpeg → Quercus_suber_0207.jpeg
# Renamed: Quercus_suber_0208.jpg → Quercus_suber_0208.jpg
# Renamed: Quercus_suber_0209.jpg → Quercus_suber_0209.jpg
# Renamed: Quercus_suber_0210.jpg → Quercus_suber_0210.jpg
# Renamed: Quercus_suber_0211.jpg → Quercus_suber_0211.jpg
# Renamed: Quercus_suber_0212.jpg → Quercus_suber_0212.jpg
# Renamed: Quercus_suber_0213.jpeg → Quercus_suber_0213.jpeg
# Renamed: Quercus_suber_0214.jpeg → Quercus_suber_0214.jpeg
# Renamed: Quercus_suber_0215.jpeg → Quercus_suber_0215.jpeg
# Renamed: Quercus_suber_0216.jpeg → Quercus_suber_0216.jpeg
# Renamed: Quercus_suber_0217.jpeg → Quercus_suber_0217.jpeg
# Renamed: Quercus_suber_0218.jpeg → Quercus_suber_0218.jpeg
# Renamed: Quercus_suber_0219.jpg → Quercus_suber_0219.jpg
# Renamed: Quercus_suber_0220.jpeg → Quercus_suber_0220.jpeg
# Renamed: Quercus_suber_0221.jpg → Quercus_suber_0221.jpg
# Renamed: Quercus_suber_0222.jpeg → Quercus_suber_0222.jpeg
# Renamed: Quercus_suber_0223.jpeg → Quercus_suber_0223.jpeg
# Renamed: Quercus_suber_0224.jpeg → Quercus_suber_0224.jpeg
# Renamed: Quercus_suber_0225.jpeg → Quercus_suber_0225.jpeg
# Renamed: Quercus_suber_0226.jpeg → Quercus_suber_0226.jpeg
# Renamed: Quercus_suber_0227.jpeg → Quercus_suber_0227.jpeg
# Renamed: Quercus_suber_0228.jpeg → Quercus_suber_0228.jpeg
# Renamed: Quercus_suber_0229.jpeg → Quercus_suber_0229.jpeg

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from tqdm import tqdm

# --- Settings ---
data_dir = "data_images"
model_path = "Tree_Identifier/models/model.pth"  # or "models/model.pth"
class_names = ["Eucalyptus globulus", "Pinus pinaster", "Quercus suber"]
num_classes = len(class_names)

# --- Model Definition ---
class DeeperCNN(nn.Module):
    def __init__(self, num_classes):
        super(DeeperCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout(0.25),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Dropout(0.25),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(0.25),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 32 * 32, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )
    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# --- Transforms ---
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# --- Load Model ---
device = torch.device("cpu")
model = torch.load(model_path, map_location=device, weights_only=False)
model.eval()

# --- Prediction Function ---
def predict_image(image_path):
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        outputs = model(image)
        probs = F.softmax(outputs, dim=1)[0]
    return probs.cpu().numpy()

# --- Store Probabilities ---
results = {cls: [] for cls in class_names}

for filename in tqdm(os.listdir(data_dir)):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
        path = os.path.join(data_dir, filename)
        try:
            probs = predict_image(path)
            for i, cls in enumerate(class_names):
                results[cls].append((filename, float(probs[i])))
        except Exception as e:
            print(f"Error with {filename}: {e}")

# --- Show Top 10 per Class ---
print("\n=== Top 10 images per class (highest confidence) ===")
for cls in class_names:
    print(f"\nClass: {cls}")
    top10 = sorted(results[cls], key=lambda x: x[1], reverse=True)[:10]
    for filename, prob in top10:
        print(f"{filename}: {prob:.4f}")
# Out:
# 100%|██████████| 593/593 [01:41<00:00,  5.87it/s]
# === Top 10 images per class (highest confidence) ===
#
# Class: Eucalyptus globulus
# Eucalyptus_globulus_0014.jpeg: 0.6492
# Eucalyptus_globulus_0139.jpeg: 0.6338
# Quercus_suber_0220.jpeg: 0.6336
# Eucalyptus_globulus_0077.jpeg: 0.6228
# Quercus_suber_0153.jpeg: 0.6188
# Eucalyptus_globulus_0045.jpeg: 0.6162
# Quercus_suber_0112.jpeg: 0.5782
# Eucalyptus_globulus_0022.jpeg: 0.5779
# Eucalyptus_globulus_0106.jpeg: 0.5754
# Eucalyptus_globulus_0132.jpeg: 0.5746
#
# Class: Pinus pinaster
# Pinus_pinaster_0157.jpeg: 0.9878
# Pinus_pinaster_0161.jpeg: 0.9817
# Pinus_pinaster_0069.jpeg: 0.9778
# Pinus_pinaster_0187.jpeg: 0.9725
# Pinus_pinaster_0133.jpeg: 0.9716
# Pinus_pinaster_0156.jpeg: 0.9709
# Pinus_pinaster_0081.jpeg: 0.9703
# Pinus_pinaster_0195.jpeg: 0.9689
# Pinus_pinaster_0068.jpeg: 0.9685
# Pinus_pinaster_0194.jpeg: 0.9667
#
# Class: Quercus suber
# Quercus_suber_0125.jpeg: 0.7444
# Quercus_suber_0001.jpeg: 0.6879
# Quercus_suber_0021.jpeg: 0.6879
# Quercus_suber_0008.jpeg: 0.6757
# Quercus_suber_0023.jpeg: 0.6510
# Quercus_suber_0101.jpeg: 0.6246
# Quercus_suber_0044.jpg: 0.6179
# Quercus_suber_0086.jpeg: 0.6174
# Quercus_suber_0019.jpg: 0.6154
# Quercus_suber_0170.jpeg: 0.6124
